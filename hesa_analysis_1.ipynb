# %% [markdown]
# # HESA Data Analysis - Experimenting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %%
files = glob.glob("C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\*.csv")

# print(files)

for f in files:
    temp_file = pd.read_csv(f)
    print(temp_file.head(20))

list = []

# for f in files:
#     temp_file = pd.read_csv(f)
#     list.append(temp_file)
#     print(f'First one done - {f} - shaped like {temp_file.shape}')

# hesa_data = pd.concat(list, axis = 0)
# print(hesa_data.shape)
# hesa_data.head(10)
# Out:
# ['C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2014-15).csv', 'C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2015-16).csv', 'C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2016-17).csv', 'C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2017-18).csv', 'C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2018-19).csv', 'C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2019-20).csv', 'C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2020-21).csv', 'C:\\Users\\keena\\OneDrive\\Documents\\Github\\HESA\\table 1-(2021-22).csv']
# C:\Users\keena\AppData\Local\Temp\ipykernel_30800\1795116717.py:6: DtypeWarning: Columns (0,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_file = pd.read_csv(f)
#                        Title  \
# 0                   Location
# 1             Academic years
# 2                Data source
# 3            Data collection
# ...
